# %% [markdown]
# # Health_Care_Data_Analysis

# %% [markdown]
# ## 1) Import the Data

# %%
pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in d:\anaconda distributer\lib\site-packages (0.0.7)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas>=1.0.0 in d:\anaconda distributer\lib\site-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in d:\anaconda distributer\lib\site-packages (from ucimlrepo) (2024.12.14)
# Requirement already satisfied: numpy>=1.26.0 in d:\anaconda distributer\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda distributer\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda distributer\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda distributer\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda distributer\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.16.0)

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 
  
# data (as pandas dataframes) 
X = heart_disease.data.features 
y = heart_disease.data.targets 
  
# metadata 
print(heart_disease.metadata) 
  
# variable information 
print(heart_disease.variables)
# Out:
# {'uci_id': 45, 'name': 'Heart Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/45/heart+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/45/data.csv', 'abstract': '4 databases: Cleveland, Hungary, Switzerland, and the VA Long Beach', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 303, 'num_features': 13, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': ['Age', 'Sex'], 'target_col': ['num'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1989, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C52P4X', 'creators': ['Andras Janosi', 'William Steinbrunn', 'Matthias Pfisterer', 'Robert Detrano'], 'intro_paper': {'ID': 231, 'type': 'NATIVE', 'title': 'International application of a new probability algorithm for the diagnosis of coronary artery disease.', 'authors': 'R. Detrano, A. Jánosi, W. Steinbrunn, M. Pfisterer, J. Schmid, S. Sandhu, K. Guppy, S. Lee, V. Froelicher', 'venue': 'American Journal of Cardiology', 'year': 1989, 'journal': None, 'DOI': None, 'URL': 'https://www.semanticscholar.org/paper/a7d714f8f87bfc41351eb5ae1e5472f0ebbe0574', 'sha': None, 'corpus': None, 'arxiv': None, 'mag': None, 'acl': None, 'pmid': '2756873', 'pmcid': None}, 'additional_info': {'summary': 'This database contains 76 attributes, but all published experiments refer to using a subset of 14 of them.  In particular, the Cleveland database is the only one that has been used by ML researchers to date.  The "goal" field refers to the presence of heart disease in the patient.  It is integer valued from 0 (no presence) to 4. Experiments with the Cleveland database have concentrated on simply attempting to distinguish presence (values 1,2,3,4) from absence (value 0).  \n   \nThe names and social security numbers of the patients were recently removed from the database, replaced with dummy values.\n\nOne file has been "processed", that one containing the Cleveland database.  All four unprocessed files also exist in this directory.\n\nTo see Test Costs (donated by Peter Turney), please see the folder "Costs" ', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'Only 14 attributes used:\r\n      1. #3  (age)       \r\n      2. #4  (sex)       \r\n      3. #9  (cp)        \r\n      4. #10 (trestbps)  \r\n      5. #12 (chol)      \r\n      6. #16 (fbs)       \r\n      7. #19 (restecg)   \r\n      8. #32 (thalach)   \r\n      9. #38 (exang)     \r\n      10. #40 (oldpeak)   \r\n      11. #41 (slope)     \r\n      12. #44 (ca)        \r\n      13. #51 (thal)      \r\n      14. #58 (num)       (the predicted attribute)\r\n\r\nComplete attribute documentation:\r\n      1 id: patient identification number\r\n      2 ccf: social security number (I replaced this with a dummy value of 0)\r\n      3 age: age in years\r\n      4 sex: sex (1 = male; 0 = female)\r\n      5 painloc: chest pain location (1 = substernal; 0 = otherwise)\r\n      6 painexer (1 = provoked by exertion; 0 = otherwise)\r\n      7 relrest (1 = relieved after rest; 0 = otherwise)\r\n      8 pncaden (sum of 5, 6, and 7)\r\n      9 cp: chest pain type\r\n        -- Value 1: typical angina\r\n        -- Value 2: atypical angina\r\n        -- Value 3: non-anginal pain\r\n        -- Value 4: asymptomatic\r\n     10 trestbps: resting blood pressure (in mm Hg on admission to the hospital)\r\n     11 htn\r\n     12 chol: serum cholestoral in mg/dl\r\n     13 smoke: I believe this is 1 = yes; 0 = no (is or is not a smoker)\r\n     14 cigs (cigarettes per day)\r\n     15 years (number of years as a smoker)\r\n     16 fbs: (fasting blood sugar > 120 mg/dl)  (1 = true; 0 = false)\r\n     17 dm (1 = history of diabetes; 0 = no such history)\r\n     18 famhist: family history of coronary artery disease (1  ...
#         name     role         type demographic  \
# 0        age  Feature      Integer         Age
# 1        sex  Feature  Categorical         Sex
# 2         cp  Feature  Categorical        None
# 3   trestbps  Feature      Integer        None
# 4       chol  Feature      Integer        None
# 5        fbs  Feature  Categorical        None
# 6    restecg  Feature  Categorical        None
# 7    thalach  Feature      Integer        None
# 8      exang  Feature  Categorical        None
# 9    oldpeak  Feature      Integer        None
# 10     slope  Feature  Categorical        None
# 11        ca  Feature      Integer        None
# 12      thal  Feature  Categorical        None
# 13       num   Target      Integer        None
#
#                                           description  units missing_values
# 0                                                None  years             no
# 1                                                None   None             no
# 2                                                None   None             no
# 3   resting blood pressure (on admission to the ho...  mm Hg             no
# 4                                   serum cholestoral  mg/dl             no
# 5                     fasting blood sugar > 120 mg/dl   None             no
# 6                                                None   None             no
# 7                         maximum heart rate achieved   None             no
# 8                             exercise induced angina   None             no
# 9   ST depression induced by exercise relative to ...   None             no
# 10                                               None   None             no
# 11  number of major vessels (0-3) colored by flour...   None            yes
# 12                                               None   None            yes
# 13                         diagnosis of heart disease   None             no

# %% [markdown]
# ## 2) Printing_The_Data

# %%
# Printing the data 
import pandas as pd
heart_df = pd.concat([X, y], axis=1)
heart_df

hdf = pd.concat([X, y], axis=1)

# %% [markdown]
# ## 3) DATA PREPROCESSING

# %% [markdown]
# ### 1) Filling NaN value to Mean

# %%
#heart_df.fillna(heart_df['ca'].mean(),heart_df['ca'],inplace = True)

mean_value = heart_df['ca'].mean()
heart_df['ca'] = heart_df['ca'].fillna(mean_value)
heart_df['ca']
heart_df


mean_value = heart_df['thal'].mean()
heart_df['thal'] = heart_df['thal'].fillna(mean_value)
heart_df['thal']
heart_df

# mode_value = heart_df['num'].mode()
 #mode_value
 #heart_df['num'] = heart_df['num'].fillna(mode_value, inplace = True)
 #heart_df['num']
 #heart_df

 #heart_df['num'].fillna(heart_df['num'].mode())
 #heart_df['num']

#heart_df.isnull().sum(
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope        ca  thal  num
# 0        3  0.000000   6.0    0
# 1        2  3.000000   3.0    2
# 2        2  2.000000   7.0    1
# 3        3  0.000000   3.0    0
# 4        1  0.000000   3.0    0
# ..     ...       ...   ...  ...
# 298      2  0.000000   7.0    1
# 299      2  2.000000   7.0    2
# 300      2  1.000000   7.0    3
# 301      2  1.000000   3.0    1
# 302      1  0.672241   3.0    0
#
# [303 rows x 14 columns]

# %% [markdown]
# ### 2) Replace Numerical Value to Charactrics

# %%
heart_df["num"].value_counts()
# Out:
# num
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# Name: count, dtype: int64

# %%
import numpy as np
heart_df['sex'] = heart_df['sex'].replace({1: 'Male', 0: 'Female'})
heart_df

heart_df['cp'] = heart_df['cp'].replace({1: 'typical angina', 2: 'atypical angina',3:'non-anginal pain',4:'asymptomatic'})
heart_df

heart_df['fbs'] = heart_df['fbs'].replace({1 : "true" , 0 : "false"})
heart_df

heart_df['restecg'] = heart_df['restecg'].replace({0:"normal",1: "abnormality",2 : "LVH"})
heart_df


heart_df['exang'] = heart_df['exang'].replace({1 : "yes" , 0 : "no"})
heart_df

heart_df['slope'] = heart_df['slope'].replace({1:"upsloping",2: "flat",3 : "downsloping"})
heart_df

heart_df['thal'] = heart_df['thal'].replace({3:"normal",6: "fixed defect",7 : " reversable defect"})
heart_df
# Out:
#      age     sex                cp  trestbps  chol    fbs restecg  thalach  \
# 0     63    Male    typical angina       145   233   true     LVH      150
# 1     67    Male      asymptomatic       160   286  false     LVH      108
# 2     67    Male      asymptomatic       120   229  false     LVH      129
# 3     37    Male  non-anginal pain       130   250  false  normal      187
# 4     41  Female   atypical angina       130   204  false     LVH      172
# ..   ...     ...               ...       ...   ...    ...     ...      ...
# 298   45    Male    typical angina       110   264  false  normal      132
# 299   68    Male      asymptomatic       144   193   true  normal      141
# 300   57    Male      asymptomatic       130   131  false  normal      115
# 301   57  Female   atypical angina       130   236  false     LVH      174
# 302   38    Male  non-anginal pain       138   175  false  normal      173
#
#     exang  oldpeak        slope        ca                thal  num
# 0      no      2.3  downsloping  0.000000        fixed defect    0
# 1     yes      1.5         flat  3.000000              normal    2
# 2     yes      2.6         flat  2.000000   reversable defect    1
# 3      no      3.5  downsloping  0.000000              normal    0
# 4      no      1.4    upsloping  0.000000              normal    0
# ..    ...      ...          ...       ...                 ...  ...
# 298    no      1.2         flat  0.000000   reversable defect    1
# 299    no      3.4         flat  2.000000   reversable defect    2
# 300   yes      1.2         flat  1.000000   reversable defect    3
# 301    no      0.0         flat  1.000000              normal    1
# 302    no      0.0    upsloping  0.672241              normal    0
#
# [303 rows x 14 columns]

# %% [markdown]
# ## 4) Final_DataFrame

# %%
heart_df
# Out:
#      age     sex                cp  trestbps  chol    fbs restecg  thalach  \
# 0     63    Male    typical angina       145   233   true     LVH      150
# 1     67    Male      asymptomatic       160   286  false     LVH      108
# 2     67    Male      asymptomatic       120   229  false     LVH      129
# 3     37    Male  non-anginal pain       130   250  false  normal      187
# 4     41  Female   atypical angina       130   204  false     LVH      172
# ..   ...     ...               ...       ...   ...    ...     ...      ...
# 298   45    Male    typical angina       110   264  false  normal      132
# 299   68    Male      asymptomatic       144   193   true  normal      141
# 300   57    Male      asymptomatic       130   131  false  normal      115
# 301   57  Female   atypical angina       130   236  false     LVH      174
# 302   38    Male  non-anginal pain       138   175  false  normal      173
#
#     exang  oldpeak        slope        ca                thal  num
# 0      no      2.3  downsloping  0.000000        fixed defect    0
# 1     yes      1.5         flat  3.000000              normal    2
# 2     yes      2.6         flat  2.000000   reversable defect    1
# 3      no      3.5  downsloping  0.000000              normal    0
# 4      no      1.4    upsloping  0.000000              normal    0
# ..    ...      ...          ...       ...                 ...  ...
# 298    no      1.2         flat  0.000000   reversable defect    1
# 299    no      3.4         flat  2.000000   reversable defect    2
# 300   yes      1.2         flat  1.000000   reversable defect    3
# 301    no      0.0         flat  1.000000              normal    1
# 302    no      0.0    upsloping  0.672241              normal    0
#
# [303 rows x 14 columns]

# %% [markdown]
# ## 5) Final_Analysis

# %% [markdown]
# ### 1) count_Reports_from_gender

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data=heart_df,x='sex')
plt.ylabel('Number of Reports')
plt.savefig("count_Reports_from_gender.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 2) Number_of_reports_agewise_for_each_gender

# %%
import os
print(os.getcwd()) 

fig, axes = plt.subplots(2, 1, figsize=(14, 6))

sns.countplot(data=heart_df[heart_df['sex'] == "Male"], x='age', ax=axes[0])
axes[0].set_title('Age Distribution for Males')
axes[0].set_ylabel('Number of Reports')
axes[0].set_xlabel('Age')


sns.countplot(data=heart_df[heart_df['sex'] == "Female"], x='age', ax=axes[1])
axes[1].set_title('Age Distribution for Females')
axes[1].set_ylabel('Number of Reports')
axes[1].set_xlabel('Age')

plt.tight_layout()
plt.savefig("D:/personal_Skill_inhancing/Project/Health/Documentation/photos/Number_of_reports_agewise_for_each_gender.png"
            ,dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\DELL\Udemy_Pandas_Jupyter_project\Data Analytics

# %% [markdown]
# ### 3) Stage wise minimum and maximum heart rate of males

# %% [markdown]
# #### 1) Stage = 0 no dieases

# %%
male_healthy = heart_df[(heart_df['num'] == 0 ) & 
               (heart_df['sex'] == "Male")]  

# Find min and max thalach
min_hr = male_healthy['thalach'].min()
max_hr = male_healthy['thalach'].max()

# Filter for only those rows with min or max thalach
filtered = male_healthy[(male_healthy['thalach'] == min_hr) | 
            (male_healthy['thalach'] == max_hr)]

# Plot
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=filtered, x='thalach')
plt.title('Male Patients without Heart Disease (Min & Max Heart Rate)')
plt.xlabel('Max Heart Rate (thalach)')
plt.ylabel('Count')
plt.savefig("D:/personal_Skill_inhancing/Project/Health/Documentation/photos/min&max_HR_0.png"
            ,dpi=300, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2) stage = 1

# %%
# Plot for Females with Heart Disease

male_healthy = heart_df[(heart_df['num'] == 1 ) & (heart_df['sex'] == "Male")]  # typical angina

# Find min and max thalach
min_hr = male_healthy['thalach'].min()
max_hr = male_healthy['thalach'].max()

# Filter for only those rows with min or max thalach
filtered = male_healthy[(male_healthy['thalach'] == min_hr) | (male_healthy['thalach'] == max_hr)]

# Plot
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=filtered, x='thalach')
plt.title('Male Patients with Stage 1 Heart Disease (Min & Max Heart Rate)')
plt.xlabel('Max Heart Rate (thalach)')
plt.ylabel('Count')
plt.savefig("D:/personal_Skill_inhancing/Project/Health/Documentation/photos/min&max_HR_1.png",dpi=300, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 3) Stage = 2

# %%
male_healthy = heart_df[(heart_df['num'] == 2 ) & (heart_df['sex'] == "Male")]  # typical angina

# Find min and max thalach
min_hr = male_healthy['thalach'].min()
max_hr = male_healthy['thalach'].max()

# Filter for only those rows with min or max thalach
filtered = male_healthy[(male_healthy['thalach'] == min_hr) | (male_healthy['thalach'] == max_hr)]

# Plot
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=filtered, x='thalach')
plt.title('Male Patients with stage 2 Heart Disease (Min & Max Heart Rate)')
plt.xlabel('Max Heart Rate (thalach)')
plt.ylabel('Count')
plt.savefig("D:/personal_Skill_inhancing/Project/Health/Documentation/photos/min&max_HR_2.png",dpi=300, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4) Stage = 3

# %%
male_healthy = heart_df[(heart_df['num'] == 3 ) & (heart_df['sex'] == "Male")]  # typical angina

# Find min and max thalach
min_hr = male_healthy['thalach'].min()
max_hr = male_healthy['thalach'].max()

# Filter for only those rows with min or max thalach
filtered = male_healthy[(male_healthy['thalach'] == min_hr) | (male_healthy['thalach'] == max_hr)]

# Plot
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=filtered, x='thalach')
plt.title('Male Patients with stage 3 Heart Disease (Min & Max Heart Rate)')
plt.xlabel('Max Heart Rate (thalach)')
plt.ylabel('Count')
plt.savefig("D:/personal_Skill_inhancing/Project/Health/Documentation/photos/min&max_HR_3.png",dpi=300, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4) Stage = 4

# %%
male_healthy = heart_df[(heart_df['num'] == 4 ) & (heart_df['sex'] == "Male")]  # typical angina

# Find min and max thalach
min_hr = male_healthy['thalach'].min()
max_hr = male_healthy['thalach'].max()

# Filter for only those rows with min or max thalach
filtered = male_healthy[(male_healthy['thalach'] == min_hr) | (male_healthy['thalach'] == max_hr)]

# Plot
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=filtered, x='thalach')
plt.title('Male Patients with stage 4 Heart Disease (Min & Max Heart Rate)')
plt.xlabel('Max Heart Rate (thalach)')
plt.ylabel('Count')
plt.savefig("D:/personal_Skill_inhancing/Project/Health/Documentation/photos/min&max_HR_4.png",dpi=300, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=heart_df, x='cp', hue='num')
plt.title('Chest Pain Type vs Heart Disease')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')

# %%
hdf['thal'] = hdf['thal'].replace({
    'normal': 3,
    'fixed defect': 6,
    'reversible defect': 7
})

# Generate correlation matrix
corr = hdf.corr()

# Plot the heatmap
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')

plt.tight_layout()
plt.show()

# %%
# Set figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# --- Left Plot: ca vs count for cp = asymptomatic ---
sns.countplot(data=heart_df[heart_df['cp'] == "asymptomatic"], x='ca', palette='Set2', ax=axes[0])
# asymptomatic, typical angina, non-anginal pain, atypical angina 
axes[0].set_title('Asymptomatic Patients: Major Vessels (ca)')
axes[0].set_xlabel('Number of Major Vessels (ca)')
axes[0].set_ylabel('Patient Count')

# --- Right Plot: thal vs num ---
sns.countplot(data=heart_df[heart_df['cp'] == "asymptomatic"], x='thal', palette='Set1', ax=axes[1])
axes[1].set_title('Thalassemia Type vs Heart Disease')
axes[1].set_xlabel('Thal (3 = Normal, 6 = Fixed Defect, 7 = Reversible Defect)')
axes[1].set_ylabel('Patient Count')
axes[1].legend(title='Heart Disease (0 = No, 1 = Yes)')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18808\1427787317.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=heart_df[heart_df['cp'] == "asymptomatic"], x='ca', palette='Set2', ax=axes[0])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18808\1427787317.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=heart_df[heart_df['cp'] == "asymptomatic"], x='thal', palette='Set1', ax=axes[1])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18808\1427787317.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend(title='Heart Disease (0 = No, 1 = Yes)')
